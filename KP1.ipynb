# %% [markdown]
#                             МІНІСТЕРСТВО ОСВІТИ І НАУКИ УКРАЇНИ
#                        НАЦІОНАЛЬНИЙ ТЕХНІЧНИЙ УНІВЕРСИТЕТ УКРАЇНИ
#                            “КИЇВСЬКИЙ ПОЛІТЕХНІЧНИЙ ІНСТИТУТ”
#                                  Кафедра біомедичної інженерії
#
#
#                                 КОМПʼЮТЕРНИЙ ПРАКТИКУМ № _1_
#
#                                з дисципліни «Обробка та аналіз БМД»
#                                  «Статистичні методи дослідження»
#
#
#                                                                        Студента 2-го курсу
#                                                                        групи БС-11
#                                                                        Бутко В.Д.
#                                          Київ 2023

# %% [markdown]
# 1. Введення даних вручну

# %%
import pandas as pd

# %%
diamonds = pd.DataFrame(
    {
    'Carat': [0.23, 0.21, 0.23, 0.29, 0.31, 0.24, 0.24],
    'Depth': [55, 61, 65, 58, 58, 57, 57],
    'Color': ['J', 'D', 'G', 'E', 'F', 'D', 'G'],
    'Premium': [False, True, False, False, False, True, False],
    'Num owners': [1, 2, 'No owners', 3, 'In preparation', 2, 1],
    'Day': [23, 25, 1, 12, 6, 3, 28],
    'Month': [12, 4, 7, 4, 10, 9, 5],
    'Year': [2012, 1983, 1891, 2001, 2021, 2012, 1994]
    }
)
print(diamonds.dtypes)
diamonds
# Out:
# Carat         float64
# Depth           int64
# Color          object
# Premium          bool
# Num owners     object
# Day             int64
# Month           int64
# Year            int64
# dtype: object
#    Carat  Depth Color  Premium      Num owners  Day  Month  Year
# 0   0.23     55     J    False               1   23     12  2012
# 1   0.21     61     D     True               2   25      4  1983
# 2   0.23     65     G    False       No owners    1      7  1891
# 3   0.29     58     E    False               3   12      4  2001
# 4   0.31     58     F    False  In preparation    6     10  2021
# 5   0.24     57     D     True               2    3      9  2012
# 6   0.24     57     G    False               1   28      5  1994

# %%
diamonds['Digging date'] = pd.to_datetime(diamonds[['Day', 'Month', 'Year']])

# %%
diamonds = diamonds.drop(columns = ['Day', 'Month', 'Year'])

# %%
print(diamonds.dtypes)
diamonds
# Out:
# Carat                  float64
# Depth                    int64
# Color                   object
# Premium                   bool
# Num owners              object
# Digging date    datetime64[ns]
# dtype: object
#    Carat  Depth Color  Premium      Num owners Digging date
# 0   0.23     55     J    False               1   2012-12-23
# 1   0.21     61     D     True               2   1983-04-25
# 2   0.23     65     G    False       No owners   1891-07-01
# 3   0.29     58     E    False               3   2001-04-12
# 4   0.31     58     F    False  In preparation   2021-10-06
# 5   0.24     57     D     True               2   2012-09-03
# 6   0.24     57     G    False               1   1994-05-28

# %% [markdown]
# 2. Завантаження даних з CSV файлу

# %% [markdown]
# 2.1. Завантаження даних з вказанням повного шляху до файлу

# %%
path = '/Users/bellzebull/Documents/КПИ/4th/ОАБД/KP1/cleaned_5250.csv'
data = pd.read_csv(path, encoding = 'utf-8')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 2.2. Завантаження файлу, що розміщений в робочій диреторії

# %%
import os

# %%
print(f'The working directory is: {os.getcwd()}')
# Out:
# The working directory is: /Users/bellzebull/Documents/КПИ/4th/ОАБД/KP1

# %%
data = pd.read_csv('cleaned_5250.csv')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 3. Відображення завантажених даних

# %%
data
# Out:
#                       name  distance  stellar_magnitude  planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307    Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300    Gas Giant
# 2          14 Andromedae b     246.0            5.23133    Gas Giant
# 3            14 Herculis b      58.0            6.61935    Gas Giant
# 4             16 Cygni B b      69.0            6.21500    Gas Giant
# ...                    ...       ...                ...          ...
# 5245                XO-7 b     764.0           10.52100    Gas Giant
# 5246              YSES 2 b     357.0           10.88500    Gas Giant
# 5247             YZ Ceti b      12.0           12.07400  Terrestrial
# 5248             YZ Ceti c      12.0           12.07400  Super Earth
# 5249             YZ Ceti d      12.0           12.07400  Super Earth
#
#       discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# ...

# %% [markdown]
# 4. Базова статистика про завантажені дані

# %%
data.shape
# Out:
# (5250, 13)

# %%
data.head(n=5)
# Out:
#                    name  distance  stellar_magnitude planet_type  \
# 0  11 Comae Berenices b     304.0            4.72307   Gas Giant
# 1    11 Ursae Minoris b     409.0            5.01300   Gas Giant
# 2       14 Andromedae b     246.0            5.23133   Gas Giant
# 3         14 Herculis b      58.0            6.61935   Gas Giant
# 4          16 Cygni B b      69.0            6.21500   Gas Giant
#
#    discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0            2007         19.40000  Jupiter               1.08    Jupiter
# 1            2009         14.74000  Jupiter               1.09    Jupiter
# 2            2008          4.80000  Jupiter               1.15    Jupiter
# 3            2002          8.13881  Jupiter               1.12    Jupiter
# 4            1996          1.78000  Jupiter               1.20    Jupiter
#
#    orbital_radius  orbital_period  eccentricity detection_method
# ...

# %%
data.tail(n=5)
# Out:
#            name  distance  stellar_magnitude  planet_type  discovery_year  \
# 5245     XO-7 b     764.0             10.521    Gas Giant            2019
# 5246   YSES 2 b     357.0             10.885    Gas Giant            2021
# 5247  YZ Ceti b      12.0             12.074  Terrestrial            2017
# 5248  YZ Ceti c      12.0             12.074  Super Earth            2017
# 5249  YZ Ceti d      12.0             12.074  Super Earth            2017
#
#       mass_multiplier mass_wrt  radius_multiplier radius_wrt  orbital_radius  \
# 5245            0.709  Jupiter              1.373    Jupiter         0.04421
# 5246            6.300  Jupiter              1.140    Jupiter       115.00000
# 5247            0.700    Earth              0.913      Earth         0.01634
# 5248            1.140    Earth              1.050      Earth         0.02156
# 5249            1.090    Earth              1.030      Earth         0.02851
#
#       orbital_period  eccentricity detection_method
# ...

# %%
data.dtypes
# Out:
# name                  object
# distance             float64
# stellar_magnitude    float64
# planet_type           object
# discovery_year         int64
# mass_multiplier      float64
# mass_wrt              object
# radius_multiplier    float64
# radius_wrt            object
# orbital_radius       float64
# orbital_period       float64
# eccentricity         float64
# detection_method      object
# dtype: object

# %% [markdown]
# 7. Використання функції 'describe'

# %%
description = data.describe()
description
# Out:
#            distance  stellar_magnitude  discovery_year  mass_multiplier  \
# count   5233.000000        5089.000000     5250.000000      5227.000000
# mean    2167.168737          12.683738     2015.732190         6.434812
# std     3245.522087           3.107571        4.307336        12.972727
# min        4.000000           0.872000     1992.000000         0.020000
# 25%      389.000000          10.939000     2014.000000         1.804000
# 50%     1371.000000          13.543000     2016.000000         4.170140
# 75%     2779.000000          15.021000     2018.000000         8.000000
# max    27727.000000          44.610000     2023.000000       752.000000
#
#        radius_multiplier  orbital_radius  orbital_period  eccentricity
# count        5233.000000     4961.000000    5.250000e+03   5250.000000
# mean            1.015121        6.962942    4.791509e+02      0.063568
# std             0.603479      138.673600    1.680445e+04      0.141424
# ...

# %%
data['name'].describe()
# Out:
# count                     5250
# unique                    5250
# top       11 Comae Berenices b
# freq                         1
# Name: name, dtype: object

# %%
data['stellar_magnitude'].describe()
# Out:
# count    5089.000000
# mean       12.683738
# std         3.107571
# min         0.872000
# 25%        10.939000
# 50%        13.543000
# 75%        15.021000
# max        44.610000
# Name: stellar_magnitude, dtype: float64

# %%
cut_data = data.iloc[0:10, :]

cut_data
# Out:
#                       name  distance  stellar_magnitude planet_type  \
# 0     11 Comae Berenices b     304.0            4.72307   Gas Giant
# 1       11 Ursae Minoris b     409.0            5.01300   Gas Giant
# 2          14 Andromedae b     246.0            5.23133   Gas Giant
# 3            14 Herculis b      58.0            6.61935   Gas Giant
# 4             16 Cygni B b      69.0            6.21500   Gas Giant
# 5             17 Scorpii b     408.0            5.22606   Gas Giant
# 6            18 Delphini b     249.0            5.51048   Gas Giant
# 7  1RXS J160929.1-210524 b     454.0           12.61800   Gas Giant
# 8              24 Bootis b     313.0            5.59000   Gas Giant
# 9           24 Sextantis b     235.0            6.45350   Gas Giant
#
#    discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0            2007         19.40000  Jupiter              1.080    Jupiter
# ...

# %%
new_data = ['gr1', 'gr1', 'gr2', 'gr1', 'gr2', 'gr2', 'gr2', 'gr2', 'gr1', 'gr2']
cut_data.insert(1, 'Group', new_data)
cut_data
# Out:
#                       name Group  distance  stellar_magnitude planet_type  \
# 0     11 Comae Berenices b   gr1     304.0            4.72307   Gas Giant
# 1       11 Ursae Minoris b   gr1     409.0            5.01300   Gas Giant
# 2          14 Andromedae b   gr2     246.0            5.23133   Gas Giant
# 3            14 Herculis b   gr1      58.0            6.61935   Gas Giant
# 4             16 Cygni B b   gr2      69.0            6.21500   Gas Giant
# 5             17 Scorpii b   gr2     408.0            5.22606   Gas Giant
# 6            18 Delphini b   gr2     249.0            5.51048   Gas Giant
# 7  1RXS J160929.1-210524 b   gr2     454.0           12.61800   Gas Giant
# 8              24 Bootis b   gr1     313.0            5.59000   Gas Giant
# 9           24 Sextantis b   gr2     235.0            6.45350   Gas Giant
#
#    discovery_year  mass_multiplier mass_wrt  radius_multiplier radius_wrt  \
# 0            2007         19.40000  Jupiter              1.080    Jupiter
# ...

# %% [markdown]
# 9. Виведення статистики з розділенням на групи

# %%
cut_data.groupby('Group').describe()
# Out:
#       distance                                                              \
#          count        mean         std   min     25%    50%     75%    max
# Group
# gr1        4.0  271.000000  149.739774  58.0  242.50  308.5  337.00  409.0
# gr2        6.0  276.833333  138.031035  69.0  237.75  247.5  368.25  454.0
#
#       stellar_magnitude            ... orbital_period         eccentricity  \
#                   count      mean  ...            75%     max        count
# Group                              ...
# gr1                 4.0  5.486355  ...          2.250     4.8          4.0
# gr2                 6.0  6.875728  ...          2.575  6505.9          6.0
#
#
#            mean       std   min    25%    50%     75%   max
# Group
# gr1    0.180000  0.150776  0.04  0.070  0.155  0.2650  0.37
# gr2    0.151667  0.261719  0.00  0.015  0.070  0.0875  0.68
#
# [2 rows x 64 columns]

# %%
cut_data.to_csv('output.csv', encoding='utf8')

# %%
description.to_csv('description.csv', encoding='utf8')
