# %% [markdown]
# Try to recreate the plots below (don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %% [markdown]
# Download titanic data from build-in data frames

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(x='fare', y='age', data = titanic, kind='kde')
fig = plt.gcf()
fig.set_size_inches(4, 4)

# %%
sns.distplot(titanic['fare'], kde=False)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)

# %%
sns.boxplot(x='pclass', y='age', data=titanic)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)

# %%
sns.barplot(x='class', y='fare', data=titanic, hue='alone')
fig = plt.gcf()
fig.set_size_inches(4.5, 3)

# %%
sns.barplot(x='alone', y='age', data=titanic)
fig = plt.gcf()
fig.set_size_inches(4.5, 3)

# %%
plot = sns.stripplot(x='alive', y='age', data=titanic, hue='class', dodge=True, s= 3)

fig = plt.gcf()
fig.set_size_inches(4.5, 3)
plt.setp(plot.get_legend().get_texts(), fontsize='6') 
plt.setp(plot.get_legend().get_title(), fontsize='7')
# Out:
# [None, None]

# %%
sns.heatmap(titanic.corr())
fig = plt.gcf()
fig.set_size_inches(4.5, 3)
# Out:
# /var/folders/c0/r0q0mjpd7_l8cztzz2kkpy_m0000gn/T/ipykernel_3484/3107123169.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(titanic.corr())

# %%
p = sns.FacetGrid(titanic, col='sex')
p = p.map(plt.hist, 'fare')
fig = plt.gcf()
fig.set_size_inches(4, 2.6)
# Out:
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
p = sns.FacetGrid(titanic, col='class', row='sex')
p = p.map(plt.scatter, 'age', 'fare')
fig = plt.gcf()
fig.set_size_inches(8, 5)
# Out:
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /Users/bellzebull/miniforge3/envs/torch-gpu/lib/python3.8/site-packages/seaborn/axisgrid.py:747: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
# ...

# %% [markdown]
# Build three customized various graphs using knowledge from:
# http://seaborn.pydata.org/tutorial/aesthetics.html

# %%
sns.set_style("ticks")

g = sns.pairplot(data=titanic, hue='class', vars=['age', 'sibsp', 'parch', 'fare'], 
             diag_kind='hist', diag_kws={'alpha': 0.8}, markers=['o', 's', 'D'], 
             plot_kws={'alpha': 0.8, 's': 40})
g.fig.subplots_adjust(top=0.95)
g.fig.suptitle('Pairplot of Titanic Dataset', fontsize=15)
plt.show()

# %%
sns.set_palette("Set2")
sns.violinplot(x='sex', y='age', hue='survived', data=titanic, split=True)
plt.title('Distribution of Age by Sex and Survival')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.legend(title='Survived', loc='upper right', fontsize=10)
fig = plt.gcf()
fig.set_size_inches(6, 6)
plt.show()

# %%
sns.swarmplot(x='class', y='age', data=titanic, hue='sex', dodge=True, palette='Set2')
plt.title('Distribution of Age by Cabin Class and Sex')
plt.xlabel('Cabin Class')
plt.ylabel('Age')
fig = plt.gcf()
fig.set_size_inches(6, 6)
plt.show()
